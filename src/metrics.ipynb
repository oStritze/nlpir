# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utils
from scipy import spatial
import statistics
import char_max_likelihood as cml
utils.setup_nltk()
# Out:
# [nltk_data] Downloading package stopwords to /home/user1/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/user1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Generate some speeches

# %%
order=15
letters=2000
pres = "bush"
lm = cml.train_char_lm(pres, order)

for i in range(0,10):
    s = cml.generate_text(lm, order, letters)
    with open("../data/bush_generated/"+str(i)+".txt", "w") as text_file:
        # drop the last word since it is often non-sensical an thus not in the vocabulary for comparison
        text_file.write(s.rsplit(' ', 1)[0])

# %% [markdown]
# # Metrics based on tf-idf

# %% [markdown]
# - 10 real docs R, 10 generated docs G
# - get tfidf for R and G (10 dicts each)
# - calculate similarity (rank) for each g to all r in R -> 10 similarity values
# - do that for all g in G -> 10 sets of 10 similarity values
# - take mean over the set of 10 values for a g -> how good is this speach
# - take mean over all 10 sets for G -> how good is the algorithm

# %% [markdown]
# - mean reciprocal rank (only takes rank)
# - or np vector aus dict.values -> cosine similarity

# %% [markdown]
# ## original speeches

# %%
tokens_docs = utils.read_all_text_files("bush")
tfidf_docs = utils.tfidf_per_doc(tokens_docs)

# %%
print(utils.top_n_per_document(tfidf_docs[0], n=20))
# Out:
# ['empower', 'agreement', 'trust', 'Iraq', 'Al', 'surge', 'extremists', 'militia', 'earmarks', 'Iraqi', 'agreements', 'Qaeda', 'deny', 'Let', 'seven', 'year', 'past', 'products', 'ask', 'Lebanon']

# %%
#tfidf_docs[0]
# Out:
# {'returns': 0.0,
#  'traveling': 0.0,
#  'tiring': 0.0,
#  'Administrator': 0.0,
#  'Code': 0.0005743159815221268,
#  'Dignity': 0.0,
#  'chose': 0.0,
#  'earn': 0.000322013439989896,
#  'plutonium': 0.0,
#  'liberator': 0.0,
#  'Weldon': 0.0,
#  'self-defense': 0.0,
#  'inspiring': 0.0,
#  'rides': 0.0,
#  'bioterrorism': 0.0,
#  'fend': 0.0,
#  'profession': 0.0,
#  'loyalty': 0.0,
#  'antibiotics': 0.0,
#  'rule': 0.0005952342247991577,
#  'or': 9.077928646177155e-05,
#  'dominating': 0.0,
#  'hemisphere': 0.00046565519134185625,
#  'desert': 0.0,
#  '25,000': 0.0,
#  'combination': 0.0,
#  'coal-fired': 0.0,
#  'Lower': 0.0,
#  '120': 0.0,
#  'knew': 0.0,
#  'Hormuz': 0.0,
#  'surest': 0.0,
#  'dime': 0.0,
#  'advantage': 0.0,
#  '100,000': 0.0004020927037876684,
#  'understandable': 0.0,
#  'sovereignty': 0.0,
#  'doubters': 0.0,
#  'sophisticated': 0.0,
#  'farther': 0.0,
#  'example': 0.0,
#  'embryonic': 0.0004020927037876684,
#  'donated': 0.0,
#  'fully': 0.0004818173615838161,
#  'communities': 0.00026033807871874283,
#  'solid': 0.0,
#  'gotten': 0.0,
#  'permanent': 0.00018477112342712748,
#  'cool': 0.0,
#  'Small': 0.0,
#  'Ways': 0.0,
#  'praise': 0.0,
#  'tariff': 0.0,
#  'Secretaries': 0.0,
#  'ideologies': 0.0,
#  'Wise': 0.0,
#  'crack': 0.0,
#  'deliberately': 0.0,
#  'blames': 0.0,
#  'Chabot': 0.0,
#  'S.': 0.0,
#  'injured': 0.0,
#  'general': 0.0,
#  'subdued': 0.0,
#  'notwithstanding': 0.0,
#  'lobby': 0.0,
#  'sixties': 0.0,
#  'refused': 0.0,
#  'if': 0.0003116699820860095,
#  'seniors': 0.0,
#  'sanctioning': 0.0,
#  'Gore': 0.0,
#  'posed': 0.0,
#  'mustard': 0.0,
#  'steps': 0.0005991606490217504,
#  'Shia': 0.0,
#  'expeditiously': 0.0,
#  'melt': 0.0,
#  'worthwhile': 0.0,
#  'contrary': 0.0,
#  'devastating': 0.0,
#  'Atlantic': 0.0004020927037876684,
#  'express': 0.0,
#  'Thailand': 0.0,
#  'HOPE': 0.0005743159815221268,
#  'Bodman': 0.0,
#  'villages': 0.0,
#  'cure-all': 0.0,
#  'Panama': 0.0004020927037876684,
#  'stalks': 0.0,
#  'indefinitely': 0.0,
#  'held': 0.00021335264980962545,
#  'secret': 0.00029343191360739794,
#  'bring': 5.764614831875174e-05,
#  'totalitarians': 0.0,
#  'trip': 0.0,
#  'Salvation': 0.0,
#  'birth': 0.0,
#  'indexing': 0.0,
#  'rigorous': 0.0,
#  'troop': 0.00035699440116158585,
#  'vitality': 0.0,
#  'violently': 0.0,
#  'apparatus': 0.0,
#  '7,000': 0.0,
#  'candidate': 0.0,
#  'Rio': 0.0,
#  'occasion': 0.0,
#  'encourages': 0.0,
#  'given': 0.00019408659928083508,
#  'respective': 0.0,
#  'consequence—a': 0.0,
#  'haul': 0.0,
#  'Release': 0.0,
#  'ultimate': 0.0,
#  'tirelessly': 0.0,
#  'shortage': 0.0,
#  '2005': 0.0,
#  'listen': 0.0,
#  'five-day-old': 0.0,
#  'confound': 0.0,
#  'converted': 0.0,
#  'baseball': 0.0,
#  'launching': 0.0004020927037876684,
#  'bounce': 0.0,
#  'deliberate': 0.0,
#  'month': 0.00039682281653277186,
#  'price': 0.0,
#  'Usama': 0.0,
#  'weakest': 0.0,
#  'guaranteed': 0.0,
#  'affecting': 0.0,
#  'Blum': 0.0,
#  'accessible': 0.00046565519134185625,
#  'sympathy': 0.0,
#  'Revolution': 0.0,
#  'hurts': 0.0,
#  'hostage': 0.0,
#  'Vulnerable': 0.0,
#  'excusing': 0.0,
#  'intelligent': 0.0,
#  'beating': 0.0,
#  'nowhere': 0.0,
#  'sentence': 0.0,
#  'commuters': 0.0,
#  'endowed': 0.0,
#  'seeking': 0.0,
#  'independence': 0.000322013439989896,
#  'Step': 0.0,
#  'sign': 0.0,
#  'Peoria': 0.0,
#  'killing': 0.0,
#  'stalk': 0.0,
#  'companionship': 0.0,
#  'lovely': 0.0,
#  'knocked': 0.0,
#  'refuses': 0.0,
#  'dental': 0.0,
#  'Armed': 0.0,
#  'mandatory': 0.0,
#  'public': 0.00036362590761881877,
#  'shared': 0.00021335264980962545,
#  'fairness': 0.0,
#  'sweeping': 0.0,
#  'shortcomings': 0.0,
#  'penalties': 0.0,
#  'different': 0.0,
#  'hesitant': 0.0,
#  'conflicts': 0.0,
#  'revealed': 0.0,
#  'Aubrey': 0.0,
#  'bomb': 0.0,
#  'oppressed': 0.0,
#  'ridding': 0.0,
#  'Anyway': 0.0,
#  'admitted': 0.00046565519134185625,
#  'possibility': 0.0,
#  'hydrogen': 0.0,
#  'feel-good': 0.0,
#  'Made': 0.0005743159815221268,
#  'contagion': 0.0,
#  'incentives': 0.0002692665773748759,
#  'Iranians': 0.0,
#  'act': 0.00029112989892125264,
#  '[': 0.0,
#  'phases': 0.0,
#  'resurrection': 0.0,
#  'journey': 0.0,
#  'pre-embryo': 0.0,
#  'custody': 0.0,
#  'generosity': 0.0,
#  'educated': 0.0,
#  'underlying': 0.0,
#  'auto': 0.0,
#  'Kurdish': 0.0,
#  'mentoring': 0.0,
#  'virtues': 0.0,
#  'guides': 0.0,
#  'ought': 0.0,
#  'executives': 0.0,
#  'Kabul': 0.0,
#  'fired': 0.0,
#  'Walsh': 0.0,
#  'Let': 0.0014671595680369896,
#  'insured': 0.0,
#  'leaders': 0.000627398086118986,
#  'unchecked': 0.0,
#  'cot': 0.0,
#  'Vice': 0.00017222327773445834,
#  'chaired': 0.0,
#  'Qadhafi': 0.0,
#  'apprised': 0.0,
#  'equity': 0.0,
#  'Abandonment': 0.0,
#  'commute': 0.0,
#  'Gunnery': 0.0,
#  'Returned': 0.0,
#  'caused': 0.0,
#  'department': 0.0,
#  'authority': 0.0,
#  '8th': 0.0,
#  'ensure': 0.0006281511577761299,
#  'Artesia': 0.0,
#  'stakes': 0.0,
#  'steel': 0.0,
#  'flaws': 0.0,
#  'deeply': 0.0,
#  'imprisoned': 0.0,
#  'residue': 0.0,
#  'stockpiles': 0.0,
#  'TV': 0.0,
#  'honorable': 0.0,
#  'stay': 0.00021335264980962545,
#  'strength—the': 0.0005743159815221268,
#  'four-and-a-half': 0.0,
#  'landslide': 0.0,
#  'show': 0.0004187674385174199,
#  'intensified': 0.0,
#  'pays': 0.0,
#  'Human': 0.0,
#  'Addressing': 0.0,
#  'Louisiana': 0.0,
#  'offense': 0.000322013439989896,
#  'Association': 0.0,
#  'Fellow': 0.0,
#  'assist': 0.0,
#  'refineries': 0.0,
#  'tolerant': 0.0,
#  'improved': 0.0004020927037876684,
#  'EU': 0.0,
#  'systematic': 0.0,
#  'responders': 0.0,
#  'offering': 0.0,
#  'permitting': 0.0,
#  'enforcement': 0.0002995803245108752,
#  'applause': 0.0,
#  'wealth': 0.0,
#  'success': 0.0002995803245108752,
#  'rent': 0.0,
#  'Walesa': 0.0,
#  'design': 0.0,
#  'walked': 0.0,
#  'preserving': 0.0,
#  'coasts': 0.0,
#  'tracking': 0.0,
#  'incompatible': 0.0,
#  'Advanced': 0.0,
#  'Abroad': 0.0,
#  'varied': 0.0,
#  'Netherlands': 0.0,
#  'philosophical': 0.0,
#  'coalitions': 0.0,
#  'spectators': 0.0,
#  'camps': 0.0,
#  'voters': 0.0,
#  'accumulates': 0.0,
#  'motivated': 0.0,
#  'Founding': 0.0,
#  'Then': 0.0,
#  'region': 0.00039050711807811424,
#  'Evan': 0.0,
#  'drivers': 0.0,
#  'hide': 0.0,
#  'long': 0.0001645174883006685,
#  'opponent': 0.0,
#  'principled': 0.0,
#  'self': 0.0,
#  'Bayh': 0.0,
#  'worldwide': 0.0,
#  'lonely': 0.0,
#  'ally': 0.0,
#  'perspective': 0.0,
#  'Texan': 0.0,
#  'joyous': 0.0,
#  'volunteered': 0.00046565519134185625,
#  'detainee': 0.0,
#  'Nelson': 0.0,
#  'last': 0.0004879762892036557,
#  'tools': 0.0004267052996192509,
#  'captive': 0.0,
#  'Pell': 0.0007139888023231717,
#  'arsenal': 0.0,
#  'Back': 0.0,
#  'intellectual': 0.0,
#  'urge': 0.0,
#  'discouraging': 0.0,
#  'development': 0.00017222327773445834,
#  'Exports': 0.00046565519134185625,
#  'volunteer': 0.0,
#  'retire': 0.0,
#  'Creator': 0.0,
#  'damn': 0.0,
#  'Ryan': 0.0,
#  'registering': 0.0,
#  'enterprises': 0.0,
#  'timely': 0.0,
#  'launch': 0.00035699440116158585,
#  'SMU': 0.0,
#  'allowing': 0.00021335264980962545,
#  'post-Hitler': 0.0,
#  'choice': 0.00036362590761881877,
#  'forward': 0.000228330999740571,
#  'dear': 0.0005743159815221268,
#  'fuel': 0.0,
#  'races': 0.0,
#  'About': 0.0,
#  'period': 0.00022986942605321005,
#  'adjustment': 0.0005743159815221268,
#  'improving': 0.0,
#  'Booo': 0.0,
#  'vacations': 0.0,
#  'quo': 0.0,
#  'previous': 0.0,
#  'court': 0.0,
#  'sovereign': 0.0,
#  'soldiers': 0.00022986942605321005,
#  'agenda—with': 0.0,
#  'Allergy': 0.0,
#  'commerce': 0.0,
#  'orphans': 0.0,
#  'becomes': 0.0,
#  'patients—to': 0.0,
#  'youngest': 0.0,
#  'facts': 0.0,
#  '2017—and': 0.0,
#  'ending': 0.0002692665773748759,
#  'have': 0.0,
#  'invented': 0.0,
#  'reunite': 0.0,
#  'Secretly': 0.0,
#  'Maryland': 0.0,
#  'NIH': 0.0,
#  'distinction': 0.0004020927037876684,
#  'cultivating': 0.0,
#  '1999': 0.0,
#  'substantially': 0.00046565519134185625,
#  'Former': 0.0,
#  'transitioning': 0.0005743159815221268,
#  'forward—optimistic': 0.0,
#  'dropped': 0.0,
#  'al-Qaeda': 0.0,
#  'flag': 0.0,
#  'Michelle': 0.0,
#  'Compton': 0.0,
#  'fleeing': 0.0,
#  'after': 0.00013942179691533023,
#  'surely': 0.0,
#  'solving': 0.0,
#  'Immigration': 0.0,
#  'stays': 0.00035699440116158585,
#  'snuck': 0.0005743159815221268,
#  'coerced': 0.0,
#  'alternatives': 0.0,
#  'transform': 0.0,
#  'exams': 0.0,
#  'Parliament': 0.0009313103826837125,
#  'wounded': 0.0002692665773748759,
#  'enterprise': 0.0,
#  'governance': 0.0,
#  'nest': 0.0,
#  'mandates': 0.0,
#  'affiliates': 0.0,
#  'main': 0.0,
#  'mournful': 0.0,
#  'maneuvers': 0.0,
#  'wearing': 0.0,
#  'livelihoods': 0.0,
#  'Pacific': 0.0,
#  'seven': 0.0014671595680369896,
#  'Changing': 0.0,
#  'emergencies': 0.0,
#  'net': 0.0,
#  'procedural': 0.0,
#  '!': 0.0,
#  'Salvador': 0.0,
#  'frightening': 0.0,
#  'proving': 0.0,
#  'In': 7.329655984616605e-05,
#  'warm': 0.0,
#  'death': 0.0,
#  'Kuwait': 0.0,
#  'tip': 0.0,
#  'them': 0.0003262439880093973,
#  'Tanzania': 0.0,
#  'capability': 0.0004020927037876684,
#  'Free': 0.0,
#  'compensation': 0.0,
#  'Pontchartrain': 0.0,
#  'risks': 0.0,
#  'comfortable': 0.0,
#  'ulcers': 0.0,
#  'reaffirming': 0.0,
#  'Coalition': 0.0,
#  'Orrin': 0.0,
#  'Welcome': 0.0,
#  'unthinkable': 0.0,
#  'Sandra': 0.0,
#  'economy—even': 0.0,
#  'across': 0.0004879762892036557,
#  'truly': 0.0004020927037876684,
#  'question': 0.0,
#  'break': 0.0004267052996192509,
#  'houses': 0.0,
#  'models': 0.0,
#  'ban': 0.0,
#  'giant': 0.0,
#  'platform': 0.0,
#  'morale': 0.0,
#  'witnessing': 0.0,
#  'gift': 0.0,
#  'Palace': 0.0,
#  'menaced': 0.0,
#  'Sixty': 0.0,
#  'respects': 0.0,
#  'ruins': 0.0,
#  'Italy': 0.0,
#  'politely': 0.0,
#  'papers': 0.0,
#  'Koran': 0.0,
#  'asks': 0.0,
#  'disintegration': 0.0005743159815221268,
#  'code': 0.0,
#  'whatever': 0.0,
#  'outrage': 0.0,
#  'style': 0.0,
#  'supportive': 0.0,
#  'job': 0.00010469185962935498,
#  'behalf': 0.0,
#  'tribulations': 0.0,
#  'arsenals': 0.0,
#  'duration': 0.0,
#  '1920': 0.0,
#  'brothers': 0.0,
#  'durable': 0.0,
#  '2,400': 0.0,
#  'fact': 0.0,
#  'Silicon': 0.0,
#  'Julie': 0.0,
#  'knowledge': 0.0,
#  'areas—from': 0.0,
#  'peace': 0.000508499900433503,
#  'memory': 0.0,
#  'praises': 0.0,
#  'targeted': 0.0,
#  '10': 0.0,
#  'Page': 0.0,
#  'intimidation': 0.0,
#  'congregations': 0.0,
#  'assassinate': 0.0,
#  'Law': 0.0,
#  'environmentally': 0.0,
#  'nationals': 0.0,
#  'bankruptcy': 0.0,
#  'treated': 0.0004020927037876684,
#  'sperm': 0.0,
#  'sound-good': 0.0,
#  'worked': 0.0,
#  '1965': 0.0,
#  'worthy': 0.000322013439989896,
#  'Division': 0.0,
#  'matchless': 0.0,
#  'openness': 0.0,
#  'hasten': 0.0,
#  'announcement': 0.0,
#  'restaurant': 0.0,
#  'hundreds': 0.0004966672219626307,
#  'Professor': 0.0,
#  'chemical': 0.0,
#  'proceeding': 0.0,
#  'polices': 0.0,
#  'fuels': 0.00046565519134185625,
#  'bite': 0.00046565519134185625,
#  'insist': 0.0,
#  'effort': 5.764614831875174e-05,
#  'heat': 0.0,
#  'invitation': 0.0,
#  'Diseases': 0.0,
#  'carefully': 0.0,
#  'admire': 0.0,
#  'reenter': 0.0,
#  'Scholarships': 0.0005743159815221268,
#  'effectively': 0.000322013439989896,
#  'longer-term': 0.0,
#  'picked': 0.0,
#  'shall': 0.0,
#  'scoring': 0.0,
#  'structure': 0.0,
#  'arrests': 0.0,
#  'purposes': 0.0,
#  'ambition': 0.0,
#  'Dust': 0.0,
#  'Ronald': 0.0,
#  'ignited': 0.0,
#  'demerit': 0.0,
#  'upwards': 0.0,
#  'upgrade': 0.0,
#  'yearn': 0.0,
#  'Having': 0.0,
#  'Decisions': 0.0,
#  'Friday': 0.00046565519134185625,
#  'Points': 0.0,
#  'while': 0.0005586912832041794,
#  'crisis': 0.0,
#  'meeting': 0.0,
#  'pastor': 0.0,
#  'backed': 0.0,
#  'order': 0.00013967282080104486,
#  'magnificently': 0.0,
#  'Bunting': 0.0,
#  'Viva': 0.0,
#  'products': 0.0013969655740255686,
#  'refundable': 0.0,
#  'retaliate': 0.0,
#  'Much': 0.0,
#  'attending': 0.0,
#  'Retreating': 0.0,
#  'inhospitable': 0.0,
#  'avenues': 0.0004020927037876684,
#  'fallible': 0.0,
#  'disappointments': 0.0,
#  'ordinary': 0.00029343191360739794,
#  'prompt': 0.0004020927037876684,
#  'Tax': 0.00035699440116158585,
#  'interesting': 0.0,
#  'wonderful': 0.0,
#  'chaos': 0.00018477112342712748,
#  'historians': 0.0,
#  'talks': 0.00046565519134185625,
#  'cords': 0.0,
#  'Flores': 0.0,
#  'staff': 0.0,
#  'expensive': 0.0,
#  'knock': 0.0,
#  'Coretta': 0.0,
#  'convicted': 0.0,
#  'paying': 0.0,
#  'uplifted': 0.0,
#  'compact': 0.0,
#  'prevent': 0.0,
#  'science': 0.00024833361098131534,
#  'island': 0.0,
#  'Above': 0.0,
#  'advantages': 0.0,
#  'city': 0.00021335264980962545,
#  'France': 0.0,
#  'mom': 0.0,
#  'depth': 0.0,
#  'dictatorships': 0.0,
#  'reign': 0.0,
#  '1995': 0.0,
#  'satisfied': 0.0,
#  'animal': 0.0,
#  'commitments': 0.00018477112342712748,
#  'doctrine': 0.0,
#  '1989': 0.0,
#  'subjects': 0.0,
#  'sensible': 0.0004020927037876684,
#  'coordinate': 0.0,
#  'destruction—but': 0.0,
#  'hydrogen-fueled': 0.0,
#  'scenario': 0.0,
#  'contact': 0.0,
#  'are': 0.0,
#  'Reading': 0.0005743159815221268,
#  'proper': 0.0,
#  'classic': 0.0,
#  'street': 0.0,
#  'ambitions': 0.0,
#  'Pursuing': 0.0,
#  'missing': 0.0,
#  'apply': 0.00022986942605321005,
#  'April': 0.00046565519134185625,
#  'BUSH': 0.0,
#  'chronic': 0.0,
#  'Howard': 0.0,
#  'Reformers': 0.0,
#  'deeds': 0.0,
#  'owes': 0.00046565519134185625,
#  'Affairs': 0.0,
#  'dent': 0.0,
#  'sole': 0.0,
#  'sights': 0.0,
#  'Problems': 0.0,
#  'weapons': 0.0,
#  'wo': 0.0,
#  'sleepless': 0.0005743159815221268,
#  'bottom': 0.0,
#  'mentioned': 0.0,
#  'outreach': 0.0,
#  'Larry': 0.0,
#  'Services': 0.0,
#  'exposing': 0.0,
#  'eternally': 0.0,
#  'elements': 0.0,
#  'swaps': 0.0,
#  'Marines': 0.0,
#  'lung': 0.0,
#  'physically': 0.0,
#  'succeed': 0.00017222327773445834,
#  'emotion': 0.0,
#  'lousy': 0.0,
#  'according': 0.0,
#  'developments': 0.0,
#  'diplomatic': 0.0,
#  'emerging': 0.0,
#  'minor': 0.0,
#  'Another': 0.0,
#  'VX': 0.0,
#  'personally': 0.0004020927037876684,
#  'disruptions': 0.0,
#  'covert': 0.0,
#  'Texas': 0.0,
#  'than': 4.479234212821259e-05,
#  '1,800': 0.0005743159815221268,
#  'end': 0.0001655643298951236,
#  'appeal': 0.0,
#  'monarchies': 0.0,
#  'fences': 0.0005743159815221268,
#  'recommended': 0.00046565519134185625,
#  'acquire': 0.0,
#  'Third': 0.0,
#  'enduring': 0.0,
#  'schooled': 0.0,
#  'what': 0.00012338811622550136,
#  'unseen': 0.0,
#  'America—an': 0.0,
#  'weekend': 0.0,
#  'summer': 0.0,
#  'God': 3.598909572730838e-05,
#  'diminished': 0.0,
#  'pray': 0.0,
#  'unified': 0.0,
#  'whirlwind': 0.0,
#  'might': 0.00013967282080104486,
#  'helped': 0.0,
#  'World': 0.0,
#  'syndrome': 0.0,
#  'everybody': 0.0,
#  'candles': 0.0,
#  'suffered': 0.0,
#  'loan': 0.0,
#  'destructive': 0.0,
#  'ruler': 0.0,
#  'part': 0.00029112989892125264,
#  '400': 0.0,
#  '200': 0.0,
#  'manner': 0.0,
#  'embassy': 0.0,
#  'thrilled': 0.0,
#  'brave': 0.00021335264980962545,
#  'makes': 0.0,
#  'defective': 0.0,
#  'amnesty': 0.0,
#  'quick': 0.0,
#  'colleges': 0.0,
#  '273': 0.0,
#  'roof': 0.0,
#  'abuts': 0.0,
#  'Strike': 0.0,
#  'Medicare/prescription': 0.0,
#  'guest': 0.0,
#  'Imagine': 0.0,
#  'LULAC': 0.0,
#  'agree': 0.00022986942605321005,
#  'customs': 0.0,
#  'founding': 0.0,
#  'systems': 0.0,
#  '125': 0.0,
#  'coverage': 0.00022986942605321005,
#  'clearer': 0.0,
#  'judges': 0.00029343191360739794,
#  'safeguards': 0.0,
#  'writers': 0.0,
#  'stage': 0.0,
#  'weary': 0.0,
#  'welcomes': 0.0,
#  'wildlife': 0.0,
#  'Patton': 0.0,
#  'Indian': 0.0,
#  'Bee': 0.0,
#  'applied': 0.0,
#  'achievement': 0.00039682281653277186,
#  'thus': 0.0,
#  'grandchildren': 0.00029343191360739794,
#  '1982': 0.0,
#  'emerge': 0.0002692665773748759,
#  'reverend': 0.0,
#  'low-income': 0.0002692665773748759,
#  'confronting': 0.0009933344439252614,
#  'resolve': 0.0,
#  'guiding': 0.0,
#  'Internet': 0.0,
#  'Any': 0.0004020927037876684,
#  'activated': 0.0,
#  'candid': 0.0,
#  'Biloxi': 0.0,
#  'Tuesday': 0.0,
#  'to': 0.0,
#  'itself': 0.0,
#  'Palestine': 0.000322013439989896,
#  'obedience': 0.0,
#  'mountain': 0.0,
#  'fly': 0.00035699440116158585,
#  'hard-working': 0.0,
#  'explanation': 0.0,
#  'stated': 0.0,
#  'conquest': 0.0,
#  'streets': 0.00022986942605321005,
#  'lessons': 0.0,
#  'represents': 0.0,
#  'bikes': 0.0,
#  'banner': 0.0,
#  'beds': 0.0,
#  'hereby': 0.0,
#  'uneven': 0.0,
#  'denying': 0.0,
#  'ceasing': 0.0,
#  'handmade': 0.0,
#  'Midlothian': 0.0,
#  'communism': 0.0,
#  'ride': 0.00046565519134185625,
#  'Independent': 0.0,
#  'evacuee': 0.0,
#  'tax—or': 0.0,
#  'grid': 0.0,
#  'repeat': 0.0,
#  'remember': 0.0,
#  'iPod': 0.0,
#  'distances': 0.0,
#  'legal—Iraq': 0.0,
#  'available': 0.0,
#  'Gotcha': 0.0,
#  'how': 0.0001212086358729396,
#  'regroup': 0.0,
#  'Would': 0.0,
#  'Eisenhower': 0.0,
#  'favor': 0.0004020927037876684,
#  'Additionally': 0.0,
#  'Baby': 0.0,
#  'uncertain': 0.0,
#  'patient': 0.0,
#  'Homestead': 0.0,
#  'top': 0.00035699440116158585,
#  'sense': 0.0,
#  'mission': 0.00035900247234446186,
#  'century': 0.0002995803245108752,
#  'Institute': 0.0,
#  'Majority': 0.0,
#  'intends': 0.0,
#  'bombers': 0.0,
#  'experience': 0.0,
#  'ambush': 0.0,
#  'made': 0.00034587688991251044,
#  'was': 0.00018331691372349326,
#  'defeatism': 0.0,
#  'laptop': 0.0,
#  'hijack': 0.0,
#  'saddling': 0.0,
#  'cameras': 0.0,
#  'surges': 0.0005743159815221268,
#  'joins': 0.0,
#  'growth': 0.0008611163886722918,
#  'quit': 0.0,
#  'porch': 0.0,
#  'three-quarters': 0.0,
#  'judged': 0.0,
#  'guys': 0.0,
#  'nine': 0.0,
#  'summon': 0.0,
#  'Gerberding': 0.0,
#  'Reaching': 0.0,
#  '52': 0.00046565519134185625,
#  'lighting': 0.0,
#  'strongholds': 0.0007139888023231717,
#  'Judd': 0.0,
#  'President-elect': 0.0,
#  'impose': 0.0,
#  'Philippines': 0.0,
#  'poison': 0.0,
#  'infections': 0.0,
#  'clouds': 0.0,
#  'caught': 0.0,
#  'Left': 0.0005868638272147959,
#  'preeminent': 0.0,
#  'Cheney': 0.00019841140826638593,
#  'side': 0.0002254656425656705,
#  'continued': 0.0,
#  'attention': 0.0,
#  'industries': 0.0,
#  'winters': 0.0,
#  'Singer': 0.0,
#  'tonight—America': 0.0,
#  'unrestricted': 0.0,
#  'lengthy': 0.0,
#  'taught': 0.0,
#  'initially': 0.0,
#  'contempt': 0.0,
#  'heroes': 0.0,
#  'evacuating': 0.0,
#  'plot': 0.00029343191360739794,
#  'injuries': 0.0,
#  'lot': 0.0,
#  'Jerusalem': 0.00046565519134185625,
#  'fortunately': 0.0,
#  'prisons': 0.0,
#  'Flush': 0.0,
#  'officer': 0.0,
#  'disarming': 0.0,
#  'savings—': 0.0,
#  'learning': 0.00021335264980962545,
#  'discouragement': 0.0,
#  'expressed': 0.0,
#  'elections': 0.00018477112342712748,
#  'Hebrew': 0.0,
#  'ready': 0.0,
#  'appeared': 0.0,
#  'deduct': 0.0,
#  'arise': 0.0,
#  'By': 0.0002692518542583464,
#  'sharing': 0.000322013439989896,
#  'thereof': 0.0,
#  'worried': 0.00046565519134185625,
#  'Such': 0.0,
#  'workers—and': 0.0,
#  'why': 0.0002793456416020897,
#  'powers': 0.00046565519134185625,
#  'anew': 0.0,
#  'insignificant': 0.0,
#  'phased': 0.0,
#  'voice': 0.0,
#  'Honor': 0.0,
#  'totaled': 0.0,
#  'reassembling': 0.0,
#  'intimidate': 0.0,
#  'disagreed': 0.0,
#  'pretend': 0.0,
#  'depends': 0.0004597388521064201,
#  'valor': 0.0004020927037876684,
#  'performed': 0.0,
#  'her': 0.0,
#  'vacation': 0.0,
#  'junior': 0.0,
#  'competes': 0.0,
#  'irritant': 0.0,
#  'dealers': 0.0,
#  'alien': 0.0,
#  'Democracies': 0.0,
#  'front': 0.0,
#  'right': 6.971089845766511e-05,
#  'Baucus': 0.0,
#  '1.4': 0.0005743159815221268,
#  'African': 0.00029343191360739794,
#  'command': 0.0,
#  'unleashed': 0.0,
#  'United': 6.785614337058021e-05,
#  'firefighter': 0.0,
#  "de-Ba'athification": 0.0005743159815221268,
#  'Prohibition': 0.0,
#  'genocidal': 0.0,
#  'upcoming': 0.0,
#  'aggressively': 0.0,
#  '17th': 0.0,
#  'whim': 0.00046565519134185625,
#  'research—at': 0.0,
#  'occupiers': 0.0,
#  'reimbursed': 0.0,
#  'attempts': 0.0,
#  'upholds': 0.000322013439989896,
#  'employers': 0.0,
#  'expenditures': 0.0,
#  'embodied': 0.00046565519134185625,
#  'Affordable': 0.0,
#  'prevented': 0.0,
#  'expenses': 0.0,
#  'Others': 0.00035699440116158585,
#  'Toby': 0.0,
#  'Escape': 0.0,
#  'hold': 0.00032121157438921074,
#  'jumped': 0.0,
#  'happiest': 0.0,
#  'Baghdad': 0.0005385331547497518,
#  'deliberation': 0.0,
#  'anticipate': 0.0,
#  'Scud-type': 0.0,
#  'Lacking': 0.0,
#  'Samarra': 0.0,
#  'acts': 0.00016060578719460537,
#  'consultations': 0.0,
#  'tightening': 0.0,
#  'consequential': 0.0,
#  'Recovery': 0.0,
#  'bound': 0.000644026879979792,
#  'bolster': 0.0,
#  'veterans': 0.0007139888023231717,
#  'pilot': 0.0,
#  'forum': 0.0,
#  'Street': 0.0,
#  'Maves': 0.0,
#  'therapies': 0.0,
#  'statute—I': 0.0,
#  'battlefields': 0.0,
#  'Ben': 0.0,
#  'invigorate': 0.0,
#  'convergence': 0.0,
#  'partisan': 0.0,
#  'Suzanne': 0.0,
#  'charged': 0.0,
#  'Uzbekistan': 0.0,
#  'experiments': 0.0,
#  'Clearly': 0.0,
#  'Jo': 0.0,
#  'settlement': 0.0,
#  'Challenge': 0.0004020927037876684,
#  'Repairing': 0.0,
#  'lift': 0.0,
#  'Leon': 0.0,
#  'gaining': 0.0,
#  'proclaimed': 0.0,
#  'Abstinence': 0.0,
#  'Safia': 0.0,
#  'control': 0.0002424172717458792,
#  'housing': 0.0010770663094995035,
#  'universal': 0.0,
#  'blood': 0.0,
#  'pillars': 0.0,
#  'Gil': 0.0,
#  'affects': 0.0,
#  'some': 0.0001240481224830976,
#  'follow': 0.00021335264980962545,
#  'effects': 0.0,
#  'relations': 0.0,
#  'produced': 0.0,
#  'positive': 0.0,
#  'owe': 0.000745000832943946,
#  'reaffirmed': 0.0,
#  'Governors': 0.0,
#  'flaunt': 0.0,
#  'consult': 0.0,
#  'unmatched': 0.0,
#  'pledge': 0.0004966672219626307,
#  'Jobs': 0.0,
#  'announcing': 0.0,
#  'before': 0.0002322196395541405,
#  'Leipzig': 0.0,
#  'free': 0.0005188153348687656,
#  'imagine': 0.0,
#  'executions': 0.0,
#  'owners': 0.0,
#  'mastermind': 0.0,
#  'Golden': 0.0,
#  'cite': 0.0,
#  'anticipating': 0.0,
#  'Medal': 0.0,
#  'increasingly': 0.0004966672219626307,
#  'lowering': 0.0,
#  'companion': 0.0,
#  'skillfully': 0.0,
#  'exports': 0.0,
#  'roll': 0.0,
#  'remote': 0.0,
#  'official': 0.0,
#  'crash': 0.0,
#  'happiness': 0.0005743159815221268,
#  'be': 0.0,
#  'Initiative—a': 0.0,
#  'unions': 0.0,
#  'lenders': 0.0,
#  'Are': 0.0,
#  'marshals': 0.0,
#  'drains': 0.0,
#  'expectation': 0.0,
#  'defuse': 0.0,
#  'June': 0.0,
#  'Prime': 0.0,
#  'Twenty-eight': 0.0,
#  'dividend': 0.0,
#  'breaking': 0.0,
#  'backdrop': 0.0,
#  'extensive': 0.0,
#  'accommodating': 0.0,
#  ...}

# %% [markdown]
# ## generated speeches

# %%
# vocabulary of all original speeches
voc = set([val for sublist in tokens_docs for val in sublist])

# %%
# calculate tfidf for generated speeches
gen_tokens_docs = utils.read_all_text_files("bush_generated")
gen_tfidf_docs = utils.tfidf_per_doc(gen_tokens_docs)

# %%
# append key:0.0 for words in vocab that are not found in the generated speeches to allow direct comparison
# also drops nonsensical words from the generated text (so far I have seen only 1 case where this happens)
gen_tfidf_docs_full = [{key:gen_tfidf_docs[i].get(key, 0.0) for key in voc} for i in range(0, len(gen_tfidf_docs))]
#gen_tfidf_docs_full[0]

# %% [markdown]
# ## Cosine Similarity

# %%
# cosine similarity between 1 generated speech and 1 real speech
r = list(tfidf_docs[0].values())
g = list(gen_tfidf_docs_full[0].values())

1 - spatial.distance.cosine(r, g)
# Out:
# 0.10478403353526622

# %%
# cosine similarity between 1 generated speech and all real speeches
cosine_similarities = []
g = list(gen_tfidf_docs_full[0].values())

for i in range(0, len(tfidf_docs)):
    r = list(tfidf_docs[i].values())
    cosine_similarities.append(1 - spatial.distance.cosine(r, g))
    
print("mean cosine similarity:", sum(cosine_similarities) / len(cosine_similarities))
print("standard deviation of cosine similarity:", statistics.stdev(cosine_similarities))
print("\n", cosine_similarities)
# Out:
# mean cosine similarity: 0.0686094275516573
# standard deviation of cosine similarity: 0.04207875394606675
#
#  [0.10478403353526622, 0.07007947764852585, 0.028532979523806512, 0.021176243843499587, 0.03637756937403536, 0.020010358613685053, 0.12067391131146221, 0.17703538489215975, 0.03450037604500855, 0.177994470856636, 0.05655198493979341, 0.03869591633931735, 0.05352768822641274, 0.05159886657921009, 0.025565882784505556, 0.04802490216524036, 0.03179880310067329, 0.04445420875750328, 0.13281541833893817, 0.09471585019523288, 0.10794090572167292, 0.08141986990554162, 0.05288896223295392, 0.0742350708843823, 0.0672702799988909, 0.026565613572904212, 0.0587228924018377, 0.015984674063799997, 0.032171738276334794, 0.05797922806165612, 0.07356135862977753, 0.04324427633992023, 0.09379241045382636, 0.12141186094092027, 0.05430511984927344, 0.03228561507322736, 0.1211788697855728, 0.0598565919887436, 0.13203800926248577]
